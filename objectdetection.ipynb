# %%
from sahi.predict import get_prediction,get_sliced_prediction,predict

# %%
from sahi.models.ultralytics import UltralyticsDetectionModel

# %%
#load the model

detect=UltralyticsDetectionModel(
    model_path='yolov8n.pt',
    confidence_threshold=0.5,
    device='cpu'
)

# %%
#run interface
result=get_sliced_prediction(
    image=r'C:\Users\admin\Desktop\CV\car street.jpg',
    detection_model=detect,
    slice_height=640,
    slice_width=640,
    overlap_height_ratio=0.2,
    overlap_width_ratio=0.2,
)
# Out:
# Performing prediction on 1 slices.

# %%
for pred in result.object_prediction_list:
    bbox=pred.bbox.to_xyxy()
    label=pred.category.name
    source=pred.score.value
    print(label)
    print(source)
    print(bbox)
# Out:
# person
# 0.7525094151496887
# [46.768089294433594, 45.48717498779297, 66.18706512451172, 97.2088623046875]
# person
# 0.6076074838638306
# [6.508805274963379, 48.259483337402344, 27.54608917236328, 112.24378204345703]
# person
# 0.5737104415893555
# [197.9840545654297, 50.609249114990234, 209.58213806152344, 87.45829772949219]
# car
# 0.8150253891944885
# [np.float64(71.84256744384766), np.float64(52.49330520629883), np.float64(159.24520874023438), np.float64(118.20582580566406)]

# %%
result.export_visuals(export_dir='./')

# %%
from sahi.slicing import slice_image

# %%
from IPython.display import Image
Image(r'C:\Users\admin\Desktop\CNN\prediction_visual.png')

# %%
detect=UltralyticsDetectionModel(
    model_path='yolov5s.pt',
    confidence_threshold=0.5,
    device='cpu'
)
# Out:
# PRO TIP  Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...

# %%
#run interface
result=get_sliced_prediction(
    image=r'C:\Users\admin\Desktop\CV\car street.jpg',
    detection_model=detect,
    slice_height=640,
    slice_width=640,
    overlap_height_ratio=0.2,
    overlap_width_ratio=0.2,
)
# Out:
# Performing prediction on 1 slices.

# %%
for pred in result.object_prediction_list:
    bbox=pred.bbox.to_xyxy()
    label=pred.category.name
    source=pred.score.value
    print(label)
    print(source)
    print(bbox)
# Out:
# person
# 0.7482935190200806
# [47.22529220581055, 46.352012634277344, 66.41988372802734, 97.1085205078125]
# person
# 0.7080985307693481
# [198.20114135742188, 49.753570556640625, 210.05075073242188, 90.13789367675781]
# person
# 0.6795247793197632
# [190.25918579101562, 48.57640838623047, 201.27516174316406, 82.22248077392578]
# person
# 0.6219891309738159
# [5.495302677154541, 48.24900436401367, 24.93427276611328, 110.35049438476562]
# car
# 0.8865531086921692
# [72.2764663696289, 56.64259338378906, 144.81578063964844, 118.47867584228516]
# car
# 0.8142061233520508
# [126.41819763183594, 52.793052673339844, 159.44268798828125, 87.42542266845703]

# %%
result.export_visuals(export_dir='./')

# %%
from sahi.slicing import slice_image

# %%
from IPython.display import Image
Image(r'C:\Users\admin\Desktop\CNN\prediction_visual.png')
